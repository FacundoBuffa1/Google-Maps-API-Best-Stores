# %% [markdown]
# ### Elección de Bares y locales comerciales utilizando la API de Google Maps
#
# * Conexión a "Places API" de Google Maps para acceder a información de locales comerciales cercanos.
# * El objetivo es asignar las coordenadas de nuestra ubicación y buscar locales en un radio de cercanía.
# * Además podemos asiganar alguna palabra clave del tipo de local/artículo/comida en que estamos interesados.
# * Podremos elegir entre aquellos locales con mayor rating.
#
# * Use the Google Maps API to choose the best stores near you. Look for restaurants, gym, groceries, etc.

# %%
# Instalamos la biblioteca de googlemaps
 
pip install -U googlemaps
# Out:
# Requirement already satisfied: googlemaps in c:\users\pepinillo\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\pepinillo\anaconda3\lib\site-packages (from googlemaps) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pepinillo\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pepinillo\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pepinillo\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pepinillo\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Principales librerías

import googlemaps
from datetime import datetime
import pprint
import time
import pandas as pd

# %%
# Ingresamos nuestra API Key generada desde Google Cloud Platform

gmaps = googlemaps.Client(key= 'Ingresar_API_Key')

# %%
# Define los parámetros de nuestra búsqueda

ubicacion = (-70.995509, -44.184060)  #Nuestras coordenadas
distancia = 0.1  #Radio en millas
palabra_clave = 'cafe'  #Que estamos buscando? Pizza, cafe, deportes, fotocopias, etc.
business_list = []

# %%
# Busqueda por ceracanía

places_result = gmaps.places_nearby(location= ubicacion, radius= distancia, open_now= False, keyword= palabra_clave)
pprint.pprint(places_result)
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -31.4248215,
#                                         'lng': -64.18909099999999},
#                            'viewport': {'northeast': {'lat': -31.42345467010727,
#                                                       'lng': -64.18779967010728},
#                                         'southwest': {'lat': -31.42615432989272,
#                                                       'lng': -64.19049932989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'Káapeh II - Gourmet Coffee - Barista House',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115016694021498683223">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'AeJbb3chTmpopjKOoexrnnA9U9LgH6H6mgdbV5qJy9oC4eQenxcdPN7tuiz8YdvUZZOgjJgatIL5hduD97nL7V2zox3b9b1HY6oLUmtg4OKd9LQa6eIzHaJXJXvgQxGHSwM6lc6fq1r8mwug-Le1HwbPYLIySE2_9mJzKBYwiiR2SIRbQJWc',
#                           'width': 3024}],
#               'place_id': 'ChIJH8VmTY-iMpQRJuNKGaouSDM',
#               'plus_code': {'compound_code': 'HRG6+39 Córdoba, Cordoba',
#                             'global_code': '47WQHRG6+39'},
#               'price_level': 2,
#               'rating': 4.7,
#               'reference': 'ChIJH8VmTY-iMpQRJuNKGaouSDM',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'store',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 473,
#               'vicinity': 'Obispo Trejo y Sanabria 775 5000, Córdoba'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -31.4252658, 'lng': -64.1892467},
#                            'viewport': {'northeast': {'lat': -31.42389352010728,
#                                                       'lng': -64.18797027010727},
#                                         'southwest': {'lat': -31.42659317989273,
#                                                       'lng': -64.19066992989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'La Vereda de Achaval - Café de Especialidad',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3096,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108639151695513871938">Gato '
#                                                 'DePesho</a>'],
#                           'photo_reference': 'AeJbb3cxqIMNAQjO0RW9KbAZZpMtXy0AOCgxUt74kBMisURx7Ij-xc-9dV-l-CHp69e6bbc9rSG0XfJv1cnIYj7p_pdo3h-Z5_hZneEmpTcXODZu6O5hpReub4iUtgHndw_9MqGjbMv24Cb-Rt32f-o77lUZDPVjbW2d6K3oRPTFjxlGYiZj',
#                           'width': 4128}],
#               'place_id': 'ChIJY_W3tIiiMpQR3GByoli0elw',
#               'plus_code': {'compound_code': 'HRF6+V8 Córdoba, Cordoba',
#                             'global_code': '47WQHRF6+V8'},
#               'price_level': 2,
#               'rating': 4.6,
#               'reference': 'ChIJY_W3tIiiMpQR3GByoli0elw',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 653,
#               'vicinity': 'Obispo Trejo y Sanabria 805, Córdoba'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -31.4238735, 'lng': -64.1856842},
#                            'viewport': {'northeast': {'lat': -31.42250242010727,
#                                                       'lng': -64.18440672010728},
#                                         'southwest': {'lat': -31.42520207989272,
#                                                       'lng': -64.18710637989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'Creambury Buen Pastor',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107658526856087713690">Angelo '
#                                                 'Mora</a>'],
#                           'photo_reference': 'AeJbb3dcJEQIEBSj0FwGMqMCNjONzMe0NxjEDzpIY1v8OKQj_zs7FgVmF4gRuJ7Omuzmd7kD9vEej-6p4UbHRQ1QNaEf2F5mNABjHAH4KN07uaa5k9Bvd2M7qEz2dKxEdseiUiY8TY-0CDwcuVTZeAiGyFhMKDjKTeND2GxyJH6u_ZpYZUsK',
#                           'width': 4000}],
#               'place_id': 'ChIJs6kChY-iMpQRx6k1osgpDwU',
#               'plus_code': {'compound_code': 'HRG7+CP Córdoba, Cordoba',
#                             'global_code': '47WQHRG7+CP'},
#               'price_level': 2,
#               'rating': 4,
#               'reference': 'ChIJs6kChY-iMpQRx6k1osgpDwU',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'store',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2357,
#               'vicinity': 'Buenos Aires 601, IMM'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -31.4275929, 'lng': -64.1872975},
#                            'viewport': {'northeast': {'lat': -31.42623017010727,
#                                                       'lng': -64.18599037010728},
#                                         'southwest': {'lat': -31.42892982989272,
#                                                       'lng': -64.18869002989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Bosque: grow café',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3800,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101088682677438584770">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'AeJbb3dolWsQed6gzTKvoB1LojcXUP2PeDeQqCTXD14dcGEUXAKRT53arR_T8oJzcUAFa8FgIenTkMgRRaeIFYmbBAg-ifDxBI6w77KYsz7orVp1Rg8sBETsf7hOKT42eNalHgvYujw5fh4DwsbCkEQAbjh1Pn3WJyEFKNDfmlwffK9q1IGf',
#                           'width': 2533}],
#               'place_id': 'ChIJbyAPWS2jMpQRuHxhE9dSYW0',
#               'plus_code': {'compound_code': 'HRC7+X3 Córdoba, Cordoba',
#                             'global_code': '47WQHRC7+X3'},
#               'rating': 4.8,
#               'reference': 'ChIJbyAPWS2jMpQRuHxhE9dSYW0',
#               'scope': 'GOOGLE',
#               'types': ['store', 'food', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 171,
#               'vicinity': 'Buenos Aires 971, Córdoba'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -31.425298,
#                                         'lng': -64.18614699999999},
#                            'viewport': {'northeast': {'lat': -31.42398927010728,
#                                                       'lng': -64.18491132010728},
#                                         'southwest': {'lat': -31.42668892989272,
#                                                       'lng': -64.18761097989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'La Befana',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2250,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102177701157009580339">María '
#                                                 'Emilia Luján</a>'],
#                           'photo_reference': 'AeJbb3dbLkip9YgNNEVr7JntC_X5udTmZKwSgB44DoGxiNhsofYesjf3h7ZhffwnFsXW1EKXqc-14HD47GXpFZxxKH9BhFSk8pcPtiGIHfQKxmrdEFIeLq7n2pc2hJ0F54rCWkqD_l6nHaSHN052ZjSzTeAZhhqbs2cwzIZYu320bmlRpr0c',
#                           'width': 4000}],
#               'place_id': 'ChIJH0Ovp4-iMpQR1RShjX7hB1A',
#               'plus_code': {'compound_code': 'HRF7+VG Córdoba, Cordoba',
#                             'global_code': '47WQHRF7+VG'},
#               'price_level': 2,
#               'rating': 4.3,
#               'reference': 'ChIJH0Ovp4-iMpQR1RShjX7hB1A',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'store',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 616,
#               'vicinity': 'Av. Hipólito Yrigoyen 413, Planta Baja, Edificio '
#                           'Renoir, Nueva Córdoba, Córdoba'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -31.423584, 'lng': -64.1873074},
#                            'viewport': {'northeast': {'lat': -31.42221857010728,
#                                                       'lng': -64.18591257010728},
#                                         'southwest': {'lat': -31.42491822989273,
#                                                       'lng': -64.18861222989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'FULANO Café de Vereda',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108130085522207271059">Joaquin '
#                                                 'Lopez Coppari</a>'],
#                           'photo_reference': 'AeJbb3e9NXSNvkggLazJcIUxjoWBZoGFRlJAcOnrDTDtCR8zbuFLCiejiSOb7o3ljrVioKFeY_xKvPZFpRg0E2vGyHBcS2zdFNwhAtOd8Px6nrH1b1onu45wdB0xUbV50Qz6V9Btkia6lGTd-uxe-H3J-wHWCSlTDYPKKd1MWG2FytlzWx9W',
#                           'width': 3024}],
#               'place_id': 'ChIJKU0JkYujMpQRN2NgyEE0Pgw',
#               'plus_code': {'compound_code': 'HRG7+H3 Córdoba, Cordoba',
#                             'global_code': '47WQHRG7+H3'},
#               'rating': 5,
#               'reference': 'ChIJKU0JkYujMpQRN2NgyEE0Pgw',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'store',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 114,
#               'vicinity': 'Av. Hipólito Yrigoyen 292, Córdoba'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -31.4267129, 'lng': -64.1871436},
#                            'viewport': {'northeast': {'lat': -31.42537952010727,
#                                                       'lng': -64.18573607010727},
#                                         'southwest': {'lat': -31.42807917989272,
#                                                       'lng': -64.18843572989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'COOFI Lunch & Workcafe',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101684792147923545424">marianita '
#                                                 'correa</a>'],
#                           'photo_reference': 'AeJbb3ebDi_u7zMZRVfHOzPt3zbIJ9WrFT_EL-5_G94kDlK7m4LGTsZFpd2fsX9BQaWOPoEfRFdIDZBj4B30_Zap3UbiDmXV4J9BDloQGse6gZDxDzNhvNv_WLxJ3iQoMkKAsj7KRYeHDOn0DPa9izVbMeaKFeTwCvTG3dlzIT310Psrz3ui',
#                           'width': 2268}],
#               'place_id': 'ChIJ3Q-OH-6jMpQRvDQx5-xss2k',
#               'plus_code': {'compound_code': 'HRF7+84 Córdoba, Cordoba',
#                             'global_code': '47WQHRF7+84'},
#               'rating': 4.5,
#               'reference': 'ChIJ3Q-OH-6jMpQRvDQx5-xss2k',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 298,
#               'vicinity': 'Buenos Aires 864, Córdoba'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -31.4244162, 'lng': -64.187677},
#                            'viewport': {'northeast': {'lat': -31.42303482010728,
#                                                       'lng': -64.18631312010726},
#                                         'southwest': {'lat': -31.42573447989272,
#                                                       'lng': -64.1890127798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'good tartas, ensaladas cafe',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1960,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106445569966218098523">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'AeJbb3d9edSnZuByROQdIEufCIeR3LfCDyAtTWYIcKCYwFElK1OzbNRhpW0tne_Xf5qjnpigiiPrk5KYkcTUW_mLmY-62RjARDUSiQOYMWEhMMxdVn13xE5NfopC5qCaQzahgXyl2jC1MgOjRO96cwnAJghyHLcPTGJ6Zcz12W8s5x6dg3xT',
#                           'width': 4032}],
#               'place_id': 'ChIJd-hT_oWiMpQRCSMrJ2LEOWY',
#               'plus_code': {'compound_code': 'HRG6+6W Córdoba, Cordoba',
#                             'global_code': '47WQHRG6+6W'},
#               'rating': 4,
#               'reference': 'ChIJd-hT_oWiMpQRCSMrJ2LEOWY',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 23,
#               'vicinity': 'Francisco N de Laprida 5, Córdoba'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -31.4252563, 'lng': -64.1867073},
#                            'viewport': {'northeast': {'lat': -31.42386752010728,
#                                                       'lng': -64.18523992010728},
#                                         'southwest': {'lat': -31.42656717989272,
#                                                       'lng': -64.18793957989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Caffè del Popolo',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4609,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115429866588250340572">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'AeJbb3dNaiQXvkNA9pLv3occmUL3oeFokeAabnJvZkErIb2fJixwoucQS2Flx05YnaiPnENH-S4NoijetjOhklSIrj9QEkvPeMhx9SkRzHvbpynz6OdoJho08Qvdi8vxAzpq739kfaMGBn4dhlWDfS02vIcYKye_0Vq3UVm6inUZwwurZL8T',
#                           'width': 3073}],
#               'place_id': 'ChIJ-3FAtyajMpQRx71TDwSmc-g',
#               'plus_code': {'compound_code': 'HRF7+V8 Córdoba, Cordoba',
#                             'global_code': '47WQHRF7+V8'},
#               'rating': 4.3,
#               'reference': 'ChIJ-3FAtyajMpQRx71TDwSmc-g',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 191,
#               'vicinity': 'Av. Hipólito Yrigoyen 398, Córdoba'}],
#  'status': 'OK'}

# %%
# En caso de que nuestra consulta arroje varias páginas de resultados "next_page_token"

business_list.extend(places_result.get('results'))
next_page_token = places_result.get('next_page_token')

# %%
# Armamos un bucle while para traer todos los resultados de cada página

while next_page_token:
    time.sleep(2)
    places_result = gmaps.places_nearby(location= ubicacion, radius= distancia, open_now= False, keyword= palabra_clave, page_token=next_page_token)
    business_list.extend(places_result.get('results'))
    next_page_token = places_result.get('next_page_token')


# Creamos un DataFrame con los resultados y lo exportamos a excel

df = pd.DataFrame(business_list)
df['url'] = 'https://www.google.com.ar/maps/place/?q=place_id:'+ df['place_id']
df.to_excel('demo_cafe_nva_cba.xlsx', index=False)

# %%
# De nuestra DataFrame seleccionamos el nombre del local, su dirección, el rating y la cantidad de opiniones recibidas

df[['name','vicinity','rating', 'user_ratings_total', 'url']].sort_values(['rating', 'user_ratings_total'], ascending=False)
# Out:
#                                           name  \
# 5                        FULANO Café de Vereda
# 3                            Bosque: grow café
# 0   Káapeh II - Gourmet Coffee - Barista House
# 1  La Vereda de Achaval - Café de Especialidad
# 6                       COOFI Lunch & Workcafe
# 4                                    La Befana
# 8                             Caffè del Popolo
# 2                        Creambury Buen Pastor
# 7                  good tartas, ensaladas cafe
#
#                                             vicinity  rating  \
# 5                 Av. Hipólito Yrigoyen 292, Córdoba     5.0
# 3                          Buenos Aires 971, Córdoba     4.8
# 0          Obispo Trejo y Sanabria 775 5000, Córdoba     4.7
# 1               Obispo Trejo y Sanabria 805, Córdoba     4.6
# 6                          Buenos Aires 864, Córdoba     4.5
# 4  Av. Hipólito Yrigoyen 413, Planta Baja, Edific...     4.3
# 8                 Av. Hipólito Yrigoyen 398, Córdoba     4.3
# 2                              Buenos Aires 601, IMM     4.0
# 7                  Francisco N de Laprida 5, Córdoba     4.0
#
#    user_ratings_total                                                url
# 5                 114  https://www.google.com.ar/maps/place/?q=place_...
# 3                 171  https://www.google.com.ar/maps/place/?q=place_...
# 0                 473  https://www.google.com.ar/maps/place/?q=place_...
# 1                 653  https://www.google.com.ar/maps/place/?q=place_...
# 6                 298  https://www.google.com.ar/maps/place/?q=place_...
# 4                 616  https://www.google.com.ar/maps/place/?q=place_...
# 8                 191  https://www.google.com.ar/maps/place/?q=place_...
# 2                2357  https://www.google.com.ar/maps/place/?q=place_...
# 7                  23  https://www.google.com.ar/maps/place/?q=place_...

# %%
#next_page_token with pause time (esto es cuando hay muchos resultados y los tira por hoja de a 20)
#time.sleep(3)
#places_results = gmaps.places_nearby(page_token = places_results['next_page_token'])
#pprint.pprint(places_results)

# %%
#Variables de Places Details
# place_id, user_ratings_total, formatted_address

# %%
#Otra forma de acceder a los resultados
#Loop por cada place de nuestra busqueda

#for place in places_result['results']:
    #my_place_id = place['place_id']
    #my_fields = ['name', 'formatted_address', 'user_ratings_total']
    #place_details = gmaps.place(place_id =my_place_id, fields= my_fields)
    #print(place_details)
# Out:
# {'html_attributions': [], 'result': {'formatted_address': 'Obispo Trejo y Sanabria 775 5000, X5000IYO Córdoba, Argentina', 'name': 'Káapeh II - Gourmet Coffee - Barista House', 'user_ratings_total': 473}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'formatted_address': 'Obispo Trejo y Sanabria 805, X5000 Córdoba, Argentina', 'name': 'La Vereda de Achaval - Café de Especialidad', 'user_ratings_total': 653}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'formatted_address': 'Buenos Aires 601, X5000 IMM, Córdoba, Argentina', 'name': 'Creambury Buen Pastor', 'user_ratings_total': 2357}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'formatted_address': 'Buenos Aires 971, X5000 Córdoba, Argentina', 'name': 'Bosque: grow café', 'user_ratings_total': 171}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'formatted_address': 'Av. Hipólito Yrigoyen 413, Planta Baja, Edificio Renoir, Nueva Córdoba, X5000JHE Córdoba, Argentina', 'name': 'La Befana', 'user_ratings_total': 616}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'formatted_address': 'Av. Hipólito Yrigoyen 292, X5010 Córdoba, Argentina', 'name': 'FULANO Café de Vereda', 'user_ratings_total': 114}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'formatted_address': 'Buenos Aires 864, X5000 Córdoba, Argentina', 'name': 'COOFI Lunch & Workcafe', 'user_ratings_total': 298}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'formatted_address': 'Francisco N de Laprida 5, X5021KRA Córdoba, Argentina', 'name': 'good tartas, ensaladas cafe', 'user_ratings_total': 23}, 'status': 'OK'}
# {'html_attributions': [], 'result': {'formatted_address': 'Av. Hipólito Yrigoyen 398, X5000 Córdoba, Argentina', 'name': 'Caffè del Popolo', 'user_ratings_total': 191}, 'status': 'OK'}
